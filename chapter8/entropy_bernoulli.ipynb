# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

e=1e-8

p = np.linspace(e,1-e, 1000)
h = -p*np.log(p)-(1-p)*np.log(1-p)


plt.plot(p,h)
plt.xlabel('probability p')
plt.ylabel('Entropy H')

plt.title('H(p)')
plt.show()
